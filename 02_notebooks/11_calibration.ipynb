# %% [markdown]
# # LLM Feature Extraction — Calibration Run (30 articles)
#
# One-shot validation notebook. Runs the new extraction prompt on a stratified
# 30-article sample and saves results to `05_reports/calibration/llm_calibration.json`.
#
# **Do not re-run after the calibration is approved** — output is a fixed validation
# artifact, not a recurring pipeline step. Production extraction is in `06_llm_features.ipynb`.
#
# Strata in `calibration_sample`:
# - `body_valid=1` — 10 articles (passed regex filter)
# - `body_valid=0` substantial — 10 articles (rejected by regex but human-judged to have real content)
# - `body_valid=0` weak — 10 articles (rejected by regex, minimal content)

# %% [markdown]
# ### Imports and setup

# %%
import sys
import os
import json
import sqlite3
from pathlib import Path

import pandas as pd
from dotenv import load_dotenv
import anthropic

load_dotenv(Path('../.env').resolve())

sys.path.insert(0, str(Path('../03_src').resolve()))
from nlp.llm_features import extract_features

client = anthropic.Anthropic(api_key=os.environ['ANTHROPIC_API_KEY'])
print('Client ready')
# Out:
# Client ready

# %% [markdown]
# ### Load calibration sample from DB

# %%
conn = sqlite3.connect('../01_data/wti_thesis.db')
df = pd.read_sql(
    'SELECT id, title, body, body_valid, bucket FROM calibration_sample',
    conn
)
conn.close()

print(f'Loaded {len(df)} articles')
print(df.groupby('bucket').size().to_string())
# Out:
# Loaded 30 articles
# bucket
# invalid_substantial    10
# invalid_weak           10
# valid                  10

# %% [markdown]
# ### Run extraction
#
# Synchronous, no batching — 30 articles. Results are NOT written to the DB.
# Output goes to `05_reports/calibration/llm_calibration.json` only.

# %%
results = {}
errors = {}

for _, row in df.iterrows():
    article_id = int(row['id'])
    try:
        features = extract_features(row['title'], row['body'], client)
        results[article_id] = {
            'id': article_id,
            'bucket': row['bucket'],
            'body_valid': int(row['body_valid']) if row['body_valid'] is not None else None,
            'title': row['title'],
            **features,
        }
        usable_str = '✓' if features['usable'] else '✗'
        print(f'[{len(results):>2}/{len(df)}] {usable_str}  {row["title"][:70]}')
    except Exception as e:
        errors[article_id] = str(e)
        print(f'ERROR id={article_id}: {e}')

print(f'\nDone — {len(results)} extracted, {len(errors)} errors')
# Out:
# [ 1/30] ✗  Top Stock Movers Now : Vertex , DoorDash , Constellation Energy , and
# [ 2/30] ✓  Oil prices fall as analysts forecast an increase in Venezuela producti
# [ 3/30] ✓  WTI Forecast : Retreats from 7 - month top , holds bullish bias near $
# [ 4/30] ✗  Crude Oil Weekly Forecast 10 / 08 : Tempting Support ( Chart )
# [ 5/30] ✗  Focus on Nigeria Non - oil Revenue Potential
# [ 6/30] ✓  Oil up on Opec+ meeting , summer driving season
# [ 7/30] ✓  Top 5 things to watch in markets in the week ahead By Investing . com
# [ 8/30] ✓  Oil recovers after surprise drawdown in US stockpiles
# [ 9/30] ✓  Global supply chains now in Goldilocks Zone : GEP Consulting tracker
# [10/30] ✓  Oil climbs with U . S . Federal Reserve pivot
# [11/30] ✓  Gran Tierra Energy Inc . Announces First Quarter 2024 Results
# [12/30] ✗  Vermilion Energy Inc . Announces Results for the Year Ended December 3
# [13/30] ✓  Is Occidental Petroleum Corporation ( OXY ) the Best Energy Stock To B
# [14/30] ✗  ALPS Advisors Inc . Expands Stake in EnLink Midstream LLC
# [15/30] ✓  Why Occidental Petroleum Stock Plunged 10 % Today
# [16/30] ✗  Is Atmos Energy Corp . ( ATO ) The Best Defensive Stock Amid Market Vo
# [17/30] ✓  Baytex Energy Corp .: Baytex Delivers Solid Second Quarter 2025 Result
# [18/30] ✓  Why Halliburton ( HAL ) Stock Is Trading Up Today
# [19/30] ✗  Is Chevron Corporation ( CVX ) The Best Crude Oil Stock To Buy Right N
# [20/30] ✗  1 Growth Stock Down 18 % to Buy Right Now
# [21/30] ✗  Petroleum prices increase ahead of Christmas
# [22/30] ✗  Stock market today : US stocks slip as traders count down to Nvidia ea
# [23/30] ✗  The Latest : Market slumps , Gaza  bloodbath and likely deaths from Me
# [24/30] ✗  Oil Prices Rise Amid US - China Trade Optimism and Iran Deal Uncertain
# [25/30] ✓  Iran Warns US Intervention Would Destabilize Region After Trump Threat
# [26/30] ✗  How China built an  energy fortres to survive oil shocks like the Iran
# [27/30] ✓  Global oil prices surge above $111 per barrel as UAE announces exit fr
# [28/30] ✗  Gasoline Market 2024 - 2032 : Industry Report , Share , Growth Opportu
# [29/30] ✗  Governments Move to Shield Economies as Oil Jumps
# [30/30] ✗  Oil jumps 1 % in New Year after US forces repel Houthis in Red Sea
#
# Done — 30 extracted, 0 errors

# %% [markdown]
# ### Save to JSON

# %%
out_path = Path('../05_reports/calibration/llm_calibration_v2.json')
out_path.parent.mkdir(parents=True, exist_ok=True)

with open(out_path, 'w') as f:
    json.dump(results, f, indent=2, default=str)

print(f'Saved: {out_path}  ({out_path.stat().st_size:,} bytes)')
# Out:
# Saved: ../05_reports/calibration/llm_calibration_v2.json  (14,170 bytes)

# %% [markdown]
# ### Summary statistics

# %%
df_res = pd.DataFrame(results.values())

n_usable = df_res['usable'].sum()
n_not_usable = (~df_res['usable']).sum()
print(f'usable=true:  {n_usable}')
print(f'usable=false: {n_not_usable}')

print('\n--- usable by bucket ---')
print(df_res.groupby('bucket')['usable'].value_counts().to_string())

print('\n--- usable by body_valid ---')
print(df_res.groupby('body_valid')['usable'].value_counts().to_string())

usable_rows = df_res[df_res['usable']]
if len(usable_rows) > 0:
    print('\n--- event_type distribution (usable articles) ---')
    from collections import Counter
    all_types = [t for row in usable_rows['event_type'].dropna() for t in row]
    for k, v in sorted(Counter(all_types).items(), key=lambda x: -x[1]):
        print(f'  {k}: {v}')

    print('\n--- sentiment_score stats (usable articles) ---')
    print(usable_rows['sentiment_score'].describe().round(3).to_string())

if errors:
    print(f'\n--- extraction errors ({len(errors)}) ---')
    for aid, msg in errors.items():
        print(f'  id={aid}: {msg}')
# Out:
# usable=true:  14
# usable=false: 16
#
# --- usable by bucket ---
# bucket               usable
# invalid_substantial  True      5
#                      False     5
# invalid_weak         False     8
#                      True      2
# valid                True      7
#                      False     3
#
# --- usable by body_valid ---
# body_valid  usable
# 0           False     13
#             True       7
# 1           True       7
#             False      3
#
# --- event_type distribution (usable articles) ---
#   supply: 6
#   geopolitical: 6
#   macro: 6
#   demand: 4
#   technical: 3
#   other: 3
#
# --- sentiment_score stats (usable articles) ---
# count    14.000
# mean      0.300
# std       0.386
# min      -0.600
# 25%       0.225
# 50%       0.300
# 75%       0.600
# max       0.700
